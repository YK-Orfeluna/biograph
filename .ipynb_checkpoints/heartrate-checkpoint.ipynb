# %% [markdown]
# # Pythonを使って心拍解析を行う
#
#
# ## 用語
# * BPM(Beat Per Minute): 1分あたりの鼓動回数
# * LF(0.05Hz-0.15Hz): 低周波成分（血圧変化＝メイヤー波を信号源とする変動波）で，副交感神経が緊張（活性化）している場合のみに現れる
# * HF(0.15Hz-0.40Hz): 高周波成分（呼吸を信号源とする変動波）で，交感神経が緊張している時も副交感神経が緊張している時も現れる
# * RRI(R-R Interval)：心拍鼓動の間隔＝前回の鼓動から次の鼓動までの時間（ミリ秒）
# * 交感神経:
# * 副交感神経:
# * PSD(PowerSpectralDensity): 時系列データを構成する波の周波数成分を現す
#
#
#  ## 心拍解析を行う
#  x軸に経過時間，y軸にRRIをとった変動波を作成して，そのPSDからLF/HF比を求める
#
#  ## [Scipy](https://docs.scipy.org)のパッケージにPSDを求めることができる関数がある
#  scipyには主に["Periodogram法"](https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.signal.lombscargle.html), ["Welch法"](https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.signal.welch.html), ["Lomb-scargle法"](https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.signal.lombscargle.html)が実装されている
#
# x軸は総経過時間である以上，均等にプロットが行われるわけではないため，"Lomb-scargle法"が適当（多分）
#
# もしくは，スプライン補間などで等間隔にプロットし直して，Welch法などの等間隔データで取得された波形を対象とした手法でPSDを計算する
#
#
#  ## 実装してみる
#
# Pythonでもできるけど，ProcessingとArduinoを組み合わせるなら以下の通り
#
# ※Arduinoには__StandardFirmata__を書き込んでおくと良い
#
# ``` heartrate.pde
# import processing.serial.*;
# import cc.arduino.*;
# Arduino arduino;
#
# PrintWriter csvHR;
#
# int HIGH = Arduino.HIGH;
# int LOW = Arduino.LOW;
#
# int TH = 1000;
#
# int HR = 0;    //the position of HR-sensor at AnalogPin
#
# int LED_HR = 13;
#
# String DATE = str(year()).substring(2) + nf(month(), 2) + nf(day(), 2);
# String C = ",";
#
# int rri;
#
# int FPS = 30;
#
# void setup(){
#   size(500, 500);
#
#   String name = DATE + "_" + nf(hour(), 2) + nf(minute(), 2) + nf(second(), 2);
#
#   println(name);
#
#   csvHR = createWriter(name + "HR.csv");
#   csvHR.println("Time Stamp,RRI");
#   csvHR.flush();
#
#   frameRate(float(FPS));
#
#   // To connect the Arduino board
#   String port = "/dev/cu.usbmodem1411";
#   //String port = "/dev/cu.usbmodem1421";
#   //String port = "/dev/cu.usbmodem1431"
#   arduino = new Arduino(this, port, 57600);
#
#   arduino.digitalWrite(LED_HR, LOW);
#
#   println("Arduino is initlized");
#   println("system is ready");
# }
#
# boolean Flag_HR = true;
# int t_pre = 0;
# void draw(){
#   background(0);
#   fill(255);
#
#   PFont font = createFont("Yu Gothic", 20, true);
#   textFont(font);
#
#   text("心拍計測", 10, 20);
#
#   int hr_value = arduino.analogRead(HR);
#
#   if (hr_value > TH){
#     arduino.digitalWrite(LED_HR, HIGH);    //心拍鼓動時にLEDを点灯させる
#   } else {
#     arduino.digitalWrite(LED_HR, LOW);
#   }
#
#   if (hr_value > TH){
#     if (Flag_HR) {
#       int t_now = millis();
#       rri = t_now - t_pre;
#
#       Flag_HR = false;
#       t_pre = t_now;
#
#       HR();
#     }
#   } else {
#     Flag_HR = true;
#   }
#
#   text("RRI: "+nf(rri, 4), 10, 200);
# }
#
# void HR(){
#   //TimeStamp, State, Trigger, RRI
#   csvHR.print(nf(hour(), 2) + nf(minute(), 2) + nf(second(), 2));
#   csvHR.print(C);
#   csvHR.println(rri);
#
#   csvHR.flush();
# }
#
#
# void keyPressed(){
#   if (key == ESC){
#     csvHR.flush();
#     csvHR.close();
#
#     arduino.digitalWrite(LED_HR, LOW);
#
#     println("Exit");
#     exit();
#   }
# }
# ```

# %%
# 必要なパッケージをimportする
import pandas as pd
import numpy as np
from scipy.signal import lombscargle
import matplotlib.pyplot as plt
% matplotlib inline

# %%
# ここでは事前に計測したRRIを用意します
# 北岸個人の心拍（約30分の間計測）

df = pd.read_csv("heartrate.csv")
data = df.values.astype(np.int64)

timestamp = data[:, 0].T
rri = data[:, 1].T
passedtime = data[:, 2].T

plt.figure()

x = passedtime.copy()  / 1000 / 60

plt.plot(x, rri, color="r", label="RRI")

plt.ylabel("RRI (mill sec.)")
plt.xlabel("passed time (min.)")

plt.legend()

plt.show()

# %%
# 拡大表示してみる
N = 100

plt.figure()

x = passedtime.copy() / 1000

plt.plot(x[:N], rri[:N])

plt.ylabel("RRI (mill sec.)")

plt.xlabel("passed time (sec.)")

plt.show()

# %%
# lombscargle関数でPSDを求める
# 周波数帯域
LF_MIN = 0.05
LF_MAX = 0.15
HF_MIN = 0.15
HF_MAX = 0.4

# 検出点の数
# 増やしても結果は大きく変わらないので，計算コストを考えるとこれくらいが妥当
NOUT = 100

# 検出したい周波数帯域
F = np.linspace(LF_MIN, HF_MAX, NOUT)

# LFとHFをわけるための敷居値
L = np.where(F<LF_MAX)[0][-1] + 1

pgram = lombscargle(passedtime[:10], rri[:10], F)

# 正規化する
normval = passedtime[:10].shape[0]
pgram = np.sqrt(4*(pgram/normval))

#plt.plot(range(NOUT), pgram, color="b")

c = []
for i in range(NOUT) :
    if i < L :
        c.append("g")
    else :
        c.append("r")

plt.plot(range(NOUT), pgram, color="black")
plt.bar(range(NOUT), pgram, width=1.0, tick_label=F, color=c)

interval = 10
plt.xticks(range(0, NOUT, interval), np.round(F, 3)[::interval], rotation=45)

plt.xlim(0, NOUT)

plt.xlabel("Frquency (Hz)")
plt.ylabel("W / Hz")

print("HF = %.3f" %np.mean(pgram[:L]))
print("LF = %.3f" %np.mean(pgram[L:]))
# Out:
# HF = 309.481
# LF = 325.882

# %%
# lombscargle関数でPSDを求める（関数にしておく）
def psd_ls(p_time, rri, method="mean") :
    # 周波数帯域
    LF_MIN = 0.05
    LF_MAX = 0.15
    HF_MIN = 0.15
    HF_MAX = 0.4

    # 検出点の数
    # 増やしても結果は大きく変わらないので，計算コストを考えるとこれくらいが妥当
    NOUT = 100

    # 検出したい周波数帯域
    F = np.linspace(LF_MIN, HF_MAX, NOUT)
    
    # LFとHFをわけるための敷居値
    L = np.where(F<LF_MAX)[0][-1] + 1

    pgram = lombscargle(p_time, rri, F)

    # 正規化する
    normval = p_time.shape[0]
    pgram = np.sqrt(4*(pgram/normval))
    
    if method=="sum" :
        HF = np.sum(pgram[:L])
        LF = np.sum(pgram[L:])
    else :
        HF = np.mean(pgram[:L])
        LF = np.mean(pgram[L:])
    return HF, LF

print(psd_ls(passedtime[:10], rri[:10]))
# Out:
# (309.48050086102694, 325.88231047764083)

# %%
# RRIの信号10個ごとにLF/HF比率を求めてプロットしてみる

N = 10

sand_x = []
sand_y = []

rslt_x = []
rslt_y = []

for x, r in enumerate(rri) :
    sand_x.append(passedtime[x])
    sand_y.append(rri[x])
    
    if len(sand_x)==N :
        hf, lf = psd_ls(np.array(sand_x, dtype=np.int64), np.array(sand_y, dtype=np.int64))
        
        rslt_x.append(sand_x[-1])
        rslt_y.append(lf/hf)
        
        sand_x = []
        sand_y = []
        
plt.figure()

plt.plot(np.array(rslt_x)/1000/60, rslt_y)

plt.xlabel("passed time (min.)")
plt.ylabel("LF/HF")
        
plt.show()

# %% [markdown]
# ## 等間隔に直してから計算してみる

# %%
# 1秒周期で補間する

from scipy import interpolate

f = interpolate.interp1d(passedtime, rri)

t_new = np.arange(60*30)[1:] * 1000
#print(t_new)
#print(passedtime)
rri_new = f(t_new)

plt.figure()

plt.plot(passedtime/1000/60, rri, '-', label="before")
plt.plot(t_new/1000/60, rri_new, "o", label="after")

plt.ylabel("RRI (mill sec.)")
plt.xlabel("passed time (min.)")

plt.legend()
plt.show()

# センサのエラーを多少軽減できてる？？

# %%
# LF/HF比を補間後のデータでやってみる

N = 10

sand_x = []
sand_y = []

rslt_x = []
rslt_y = []

for x, r in enumerate(rri_new) :
    sand_x.append(t_new[x])
    sand_y.append(rri_new[x])
    
    if len(sand_x)==N :
        hf, lf = psd_ls(np.array(sand_x, dtype=np.int64), np.array(sand_y, dtype=np.int64))
        
        rslt_x.append(sand_x[-1])
        rslt_y.append(lf/hf)
        
        sand_x = []
        sand_y = []
        
plt.figure()

plt.plot(np.array(rslt_x)/1000/60, rslt_y)

plt.xlabel("passed time (min.)")
plt.ylabel("LF/HF")
        
plt.show()
